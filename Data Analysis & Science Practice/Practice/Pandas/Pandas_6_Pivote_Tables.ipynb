# %%
import pandas as pd
import numpy as np

# %%
data = {
'Date': pd.date_range('2023-01-01', periods=20),
'Product': ['A', 'B', 'C', 'D'] * 5,
'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
'Sales': np.random.randint(100, 1000, 20),
'Units': np.random.randint(10, 100, 20),
'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df ['Month'] = df ['Date'].dt.month_name()
df['Quarter'] = 'Q' + df ['Date'].dt. quarter.astype(str)

# %%
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    992     85   John  January      Q1
# 1  2023-01-02       B   West    379     56   Mary  January      Q1
# 2  2023-01-03       C  North    463     10    Bob  January      Q1
# 3  2023-01-04       D  South    924     32  Alice  January      Q1
# 4  2023-01-05       A   East    435     86   John  January      Q1
# 5  2023-01-06       B   West    140     14   Mary  January      Q1
# 6  2023-01-07       C  North    597     21    Bob  January      Q1
# 7  2023-01-08       D  South    607     23  Alice  January      Q1
# 8  2023-01-09       A   East    662     87   John  January      Q1
# 9  2023-01-10       B   West    471     40   Mary  January      Q1
# 10 2023-01-11       C  North    648     14    Bob  January      Q1
# 11 2023-01-12       D  South    643     46  Alice  January      Q1
# 12 2023-01-13       A   East    906     50   John  January      Q1
# 13 2023-01-14       B   West    174     13   Mary  January      Q1
# 14 2023-01-15       C  North    822     17    Bob  January      Q1
# 15 2023-01-16       D  South    456     74  Alice  January      Q1
# 16 2023-01-17       A   East    181     16   John  January      Q1
# 17 2023-01-18       B   West    506     16   Mary  January      Q1
# 18 2023-01-19       C  North    472     18    Bob  January      Q1
# 19 2023-01-20       D  South    993     37  Alice  January      Q1

# %%
pivote1 = pd.pivot_table(df,values='Sales',index='Region',columns='Product')
pivote1
# Out:
# Product      A      B      C      D
# Region
# East     635.2    NaN    NaN    NaN
# North      NaN    NaN  600.4    NaN
# South      NaN    NaN    NaN  724.6
# West       NaN  334.0    NaN    NaN

# %%
pivote2 = pd.pivot_table(df,values=['Sales','Units'],index='Region',columns='Product',aggfunc='median')
pivote2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     662.0    NaN    NaN    NaN  85.0   NaN   NaN   NaN
# North      NaN    NaN  597.0    NaN   NaN   NaN  17.0   NaN
# South      NaN    NaN    NaN  643.0   NaN   NaN   NaN  37.0
# West       NaN  379.0    NaN    NaN   NaN  16.0   NaN   NaN

# %%
pd.crosstab(df['Sales'],df['Region'])
# Out:
# Region  East  North  South  West
# Sales
# 140        0      0      0     1
# 174        0      0      0     1
# 181        1      0      0     0
# 379        0      0      0     1
# 435        1      0      0     0
# 456        0      0      1     0
# 463        0      1      0     0
# 471        0      0      0     1
# 472        0      1      0     0
# 506        0      0      0     1
# 597        0      1      0     0
# 607        0      0      1     0
# 643        0      0      1     0
# 648        0      1      0     0
# 662        1      0      0     0
# 822        0      1      0     0
# 906        1      0      0     0
# 924        0      0      1     0
# 992        1      0      0     0
# 993        0      0      1     0

# %%
pd.crosstab(df['Product'],df['Region'])
# Out:
# Region   East  North  South  West
# Product
# A           5      0      0     0
# B           0      0      0     5
# C           0      5      0     0
# D           0      0      5     0
