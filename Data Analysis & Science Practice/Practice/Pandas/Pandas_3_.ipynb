# %%
import pandas as pd
import numpy as np

# %%
dict ={
    "Name": ["Atharv",np.nan,"Rucha"],
    "Age": [ 12,np.nan,45]
}

print(dict)
# Out:
# {'Name': ['Atharv', nan, 'Rucha'], 'Age': [12, nan, 45]}

# %%
df = pd.DataFrame(dict)
print(df)
# Out:
#      Name   Age
# 0  Atharv  12.0
# 1     NaN   NaN
# 2   Rucha  45.0

# %%
df.isna()
# Out:
#     Name    Age
# 0  False  False
# 1   True   True
# 2  False  False

# %%
df.isnull()
# Out:
#     Name    Age
# 0  False  False
# 1   True   True
# 2  False  False

# %%
df.isnull().sum()
# Out:
# Name    1
# Age     1
# dtype: int64

# %%
df.dropna()
# Out:
#      Name   Age
# 0  Atharv  12.0
# 2   Rucha  45.0

# %%
df.fillna(1)
# Out:
#      Name   Age
# 0  Atharv  12.0
# 1       1   1.0
# 2   Rucha  45.0

# %%
values = {"Name":"Milind","Age":143}
df.fillna(values)
# Out:
#      Name    Age
# 0  Atharv   12.0
# 1  Milind  143.0
# 2   Rucha   45.0
