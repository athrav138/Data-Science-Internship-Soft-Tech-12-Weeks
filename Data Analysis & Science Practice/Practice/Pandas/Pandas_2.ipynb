# %%
import pandas as pd

# %%
dict = {
    "Name":["Atharv","Ram"],
    "Age":[12,17],
    "Salary":[150000,190000]
}

df = pd.DataFrame(dict)
df
# Out:
#      Name  Age  Salary
# 0  Atharv   12  150000
# 1     Ram   17  190000

# %%
list = [
    ["Atharv","Milind","Suryavanshi"],
    ["Rucha","Milind","Suryavanshi"]
]

df2 = pd.DataFrame(list)
print(df2)
# Out:
#         0       1            2
# 0  Atharv  Milind  Suryavanshi
# 1   Rucha  Milind  Suryavanshi

# %%
list = [
    ["Atharv","Milind","Suryavanshi"],
    ["Rucha","Milind","Suryavanshi"]
]
col = ["First Name","Middle Name","Last Name"]
df2 = pd.DataFrame(list,columns=col)
print(df2)
# Out:
#   First Name Middle Name    Last Name
# 0     Atharv      Milind  Suryavanshi
# 1      Rucha      Milind  Suryavanshi

# %%
df2["Age"] = [10,23]
print(df2)
# Out:
#   First Name Middle Name    Last Name  Age
# 0     Atharv      Milind  Suryavanshi   10
# 1      Rucha      Milind  Suryavanshi   23

# %%
df2
# Out:
#   First Name Middle Name    Last Name  Age
# 0     Atharv      Milind  Suryavanshi   10
# 1      Rucha      Milind  Suryavanshi   23

# %%
df
# Out:
#      Name  Age  Salary
# 0  Atharv   10  150000
# 1     Ram   23  190000

# %%
df["Age"]
# Out:
# 0    10
# 1    23
# Name: Age, dtype: int64

# %%
df.drop('Age',axis=1,inplace=True)

# %%
df
# Out:
#      Name  Salary
# 0  Atharv  150000
# 1     Ram  190000

# %%
df
#df2
# Out:
#      Name  Salary
# 0  Atharv  150000
# 1     Ram  190000

# %%
df.drop(1,axis=0)
# Out:
#      Name  Salary
# 0  Atharv  150000

# %%
df
# Out:
#      Name  Salary
# 0  Atharv  150000
# 1     Ram  190000

# %%
df.loc[[0]]
# Out:
#      Name  Salary
# 0  Atharv  150000

# %%
df.iloc[0,1]
# Out:
# np.int64(150000)

# %%
df.iloc[1:2,0:2]
# Out:
#   Name  Salary
# 1  Ram  190000

# %%
df[df['Salary']>150000]
# Out:
#   Name  Salary
# 1  Ram  190000

# %%
df[(df['Salary']>150000) & (df['Name']=='Ram')]
# Out:
#   Name  Salary
# 1  Ram  190000
